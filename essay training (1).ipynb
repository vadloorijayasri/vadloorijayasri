# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jayasree\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jayasree\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import numpy as np
import re
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\Jayasree\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
data= pd.read_csv('./data1/training_set_rel3.tsv', sep='\t', encoding='ISO-8859-1')

# %%
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# 0             NaN             NaN            NaN  ...            NaN
# 1             NaN             NaN            NaN  ...            NaN
# 2             NaN             NaN            NaN  ...            NaN
# 3             NaN             NaN            NaN  ...            NaN
# 4             NaN             NaN            NaN  ...            NaN
#
#    rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait3  rater3_trait4  rater3_trait5  rater3_trait6
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 28 columns]

# %%
data.isnull().any()
# Out:
# essay_id          False
# essay_set         False
# essay             False
# rater1_domain1    False
# rater2_domain1    False
# rater3_domain1     True
# domain1_score     False
# rater1_domain2     True
# rater2_domain2     True
# domain2_score      True
# rater1_trait1      True
# rater1_trait2      True
# rater1_trait3      True
# rater1_trait4      True
# rater1_trait5      True
# rater1_trait6      True
# rater2_trait1      True
# rater2_trait2      True
# rater2_trait3      True
# rater2_trait4      True
# rater2_trait5      True
# rater2_trait6      True
# rater3_trait1      True
# rater3_trait2      True
# rater3_trait3      True
# rater3_trait4      True
# rater3_trait5      True
# rater3_trait6      True
# dtype: bool

# %%
data= data.dropna(axis=1)
data= data.drop(columns=['rater1_domain1', 'rater2_domain1'])

# %%
data.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  Dear local newspaper, I think effects computer...
# 1         2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2         3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3         4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4         5          1  Dear @LOCATION1, I know having computers has a...
#
#    domain1_score
# 0              8
# 1              9
# 2              7
# 3             10
# 4              8

# %%
x=data.iloc[:,0:3]
y=data.iloc[:,3]

# %%
x
# Out:
#        essay_id  essay_set                                              essay
# 0             1          1  Dear local newspaper, I think effects computer...
# 1             2          1  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2             3          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3             4          1  Dear Local Newspaper, @CAPS1 I have found that...
# 4             5          1  Dear @LOCATION1, I know having computers has a...
# 5             6          1  Dear @LOCATION1, I think that computers have a...
# 6             7          1  Did you know that more and more people these d...
# 7             8          1  @PERCENT1 of people agree that computers make ...
# 8             9          1  Dear reader, @ORGANIZATION1 has had a dramatic...
# 9            10          1  In the @LOCATION1 we have the technology of a ...
# 10           11          1  Dear @LOCATION1, @CAPS1 people acknowledge the...
# 11           12          1  Dear @CAPS1 @CAPS2 I feel that computers do ta...
# 12           13          1  Dear local newspaper I raed ur argument on the...
# 13           14          1  My three detaileds for this news paper article...
# 14           15          1  Dear, In this world today we should have every...
# 15           16          1  Dear @ORGANIZATION1, The computer blinked to l...
# 16           17          1  Dear Local Newspaper, I belive that computers ...
# 17           18          1  Dear Local Newspaper, I must admit that the ex...
# 18           19          1  I aegre waf the evansmant ov tnachnolage. The ...
# 19           20          1  Well computers can be a good or a bad thing. I...
# 20           21          1  Dear @CAPS1 of the @CAPS2 @CAPS3 daily, I am w...
# 21           22          1  Dear local Newspaper @CAPS1 a take all your co...
# 22           23          1  Dear local newspaper, @CAPS1 you ever see a ch...
# 23           24          1  Dear local newspaper, I've heard that not many...
# 24           25          1  Dear @CAPS1, @CAPS2 off, I beileve that comput...
# 25           26          1  Do you think that computers are useless? Or do...
# 26           27          1  Computers a good because you can get infermati...
# 27           28          1  Dear Newspaper, Computers are high tec and hav...
# 28           29          1  Dear local newspaper, @CAPS1 people throughout...
# 29           30          1  Dear Newspaper People, I think that computers ...
# ...         ...        ...                                                ...
# 12946     21592          8   We all understand the benefits of laughter. L...
# 12947     21594          8        It was midsummer, and i could feel the c...
# 12948     21595          8   Have you ever experienced a time with your fr...
# 12949     21596          8   I woke up just like any other day happy yet l...
# 12950     21598          8   Laughter is an important part of my life, eit...
# 12951     21599          8   I sat at the table, speechless, as they told ...
# 12952     21601          8   As I remember back, it was @DATE1. It was a h...
# 12953     21603          8   Those eyes, it was like I was looking out int...
# 12954     21604          8  Some say that laugh is the common language bet...
# 12955     21605          8   Laughter is an integral element to many situa...
# 12956     21606          8  One time I was at my friend @PERSON1's house, ...
# 12957     21607          8   LAUGHTER @CAPS1 knows that laughter is a heal...
# 12958     21608          8  One thing that people in the world love to do ...
# 12959     21609          8   Laughter, to me, is an important aspect of my...
# 12960     21610          8   People always say that the worst parts of lif...
# 12961     21611          8   Why is it that people can look back at someth...
# 12962     21613          8   Before my best friend moved away, we would st...
# 12963     21615          8                                @ORGANIZATION1  ...
# 12964     21617          8   Morose and somnolent, I woke up. I woke up to...
# 12965     21618          8   A while back my mom had decided to send me to...
# 12966     21619          8                              I dont like computers
# 12967     21620          8   Everyone knows how important a laugh can be. ...
# 12968     21621          8   Laughter is an important part of my family. W...
# 12969     21623          8   laughter is an important part of any kind of ...
# 12970     21624          8  Sometime ago on a hot @DATE1 day my @NUM1 ,@PE...
# 12971     21626          8   In most stories mothers and daughters are eit...
# 12972     21628          8   I never understood the meaning laughter is th...
# 12973     21629          8  When you laugh, is @CAPS5 out of habit, or is ...
# 12974     21630          8                                 Trippin' on fen...
# 12975     21633          8   Many people believe that laughter can improve...
#
# [12976 rows x 3 columns]

# %%
y
# Out:
# 0         8
# 1         9
# 2         7
# 3        10
# 4         8
# 5         8
# 6        10
# 7        10
# 8         9
# 9         9
# 10        8
# 11        8
# 12        7
# 13        6
# 14        6
# 15       12
# 16        8
# 17        8
# 18        4
# 19        6
# 20        8
# 21        3
# 22       10
# 23       11
# 24        8
# 25        9
# 26        4
# 27        9
# 28        9
# 29        8
#          ..
# 12946    40
# 12947    32
# 12948    36
# 12949    31
# 12950    30
# 12951    47
# 12952    40
# 12953    35
# 12954    33
# 12955    36
# 12956    36
# 12957    48
# 12958    40
# 12959    40
# 12960    40
# 12961    42
# 12962    40
# 12963    32
# 12964    36
# 12965    40
# 12966    10
# 12967    33
# 12968    44
# 12969    35
# 12970    30
# 12971    35
# 12972    32
# 12973    40
# 12974    40
# 12975    40
# Name: domain1_score, Length: 12976, dtype: int64

# %%
min_scores = [-1, 2, 1, 0, 0, 0, 0, 0, 0]
max_scores = [-1, 12, 6, 3, 3, 4, 4, 30, 60]

# %% [markdown]
# # preprocessing

# %%
#removing the extra characters other than alphabets and stopwords and tokenizing the words
def essay_to_wordlist(essay_v):
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    stops = set(stopwords.words("english"))
    words = [w for w in words if not w in stops]
    return (words)

#Tokenize the senstences and call essay_to_wordlist() for word tokenization.
def essay_to_sentences(essay_v):
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sentences = tokenizer.tokenize(essay_v.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(essay_to_wordlist(raw_sentence))
    return sentences

# %%
#Feature vector is made from the words list of an essay.
def makeFeatureVec(words, model, num_features):
    featureVec = np.zeros((num_features,),dtype="float32")
    num_words = 0.
    index2word_set = set(model.wv.index_to_key)
    for word in words:
        if word in index2word_set:
            num_words += 1
            featureVec = np.add(featureVec,model.wv[word])        
    featureVec = np.divide(featureVec,num_words)
    return featureVec

#Word vectors are generated for Word2Vec model
def getAvgFeatureVecs(essays, model, num_features):
    counter = 0
    essayFeatureVecs = np.zeros((len(essays),num_features),dtype="float32")
    for essay in essays:
        essayFeatureVecs[counter] = makeFeatureVec(essay, model, num_features)
        counter = counter + 1
    return essayFeatureVecs

# %%
#the dataset is split to training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 0)

# %%
x_train.shape
# Out:
# (10380, 3)

# %%
x_test.shape
# Out:
# (2596, 3)

# %%
train_essays = x_train['essay']
test_essays = x_test['essay']

# %%
sentences = []
# Obtaining all sentences from the training essays.
for essay in train_essays:
    sentences += essay_to_sentences(essay)

# %%
sentences
# Out:
# [['essay', 'author', 'talking', 'journey'],
#  ['shows',
#   'give',
#   'ends',
#   'almost',
#   'way',
#   'began',
#   'shows',
#   'people',
#   'stay',
#   'attached',
#   'past',
#   'reasons',
#   'believe',
#   'author',
#   'concludes',
#   'story',
#   'paragraph'],
#  ['shows',
#   'people',
#   'give',
#   'even',
#   'though',
#   'failed',
#   'test',
#   'try',
#   'later',
#   'pass'],
#  ['also',
#   'story',
#   'ends',
#   'way',
#   'begins',
#   'taking',
#   'test',
#   'getting',
#   'ready',
#   'good',
#   'way',
#   'writing'],
#  ['one',
#   'last',
#   'thing',
#   'shows',
#   'people',
#   'become',
#   'attached',
#   'past',
#   'look',
#   'one',
#   'thing',
#   'reminds',
#   'month',
#   'fall',
#   'apart',
#   'takes',
#   'test',
#   'see',
#   'look',
#   'familiar',
#   'flowers',
#   'without',
#   'falling',
#   'apart'],
#  ['story',
#   'winter',
#   'hibiscus',
#   'minfong',
#   'ho',
#   'think',
#   'ending',
#   'paragraph',
#   'show',
#   'saeng',
#   'given'],
#  ['says', 'come', 'back', 'take', 'test', 'talking', 'hibiscus', 'geese'],
#  ['things', 'remind', 'home'],
#  ['reminders', 'home', 'come', 'give', 'strength', 'power', 'take', 'test'],
#  ['shows', 'even', 'though', 'failed', 'give', 'try'],
#  ['think', 'purpose', 'paragraph'],
#  ['show', 'saeng', 'given'],
#  ['excerpt',
#   'mooring',
#   'mast',
#   'marcia',
#   'amidon',
#   'l',
#   'sted',
#   'many',
#   'obstacles',
#   'builders',
#   'faced',
#   'attempting',
#   'allow',
#   'dirigibles',
#   'dock'],
#  ['one', 'reason', 'safety'],
#  ['paragraph',
#   'num',
#   'excerpts',
#   'explains',
#   'dirigibles',
#   'outside',
#   'united',
#   'states',
#   'used',
#   'hydrogen',
#   'rather',
#   'helium',
#   'hydrogen',
#   'highly',
#   'flammable'],
#  ['shows',
#   'us',
#   'accident',
#   'happen',
#   'mast',
#   'densely',
#   'populated',
#   'area',
#   'like',
#   'downtown',
#   'new',
#   'york',
#   'accident',
#   'could',
#   'get',
#   'ugly'],
#  ['another', 'reason', 'nature'],
#  ['paragraph',
#   'num',
#   'explains',
#   'winds',
#   'top',
#   'building',
#   'constantly',
#   'shifting',
#   'due',
#   'violent',
#   'air',
#   'currents'],
#  ['another',
#   'safety',
#   'issue',
#   'dirigibles',
#   'would',
#   'dangling',
#   'high',
#   'pedestrians',
#   'street'],
#  ['third',
#   'obstacle',
#   'existing',
#   'law',
#   'airships',
#   'flying',
#   'low',
#   'urban',
#   'areas'],
#  ['see', 'obstacles', 'builders', 'faced'],
#  ['features', 'setting', 'affecting', 'cyclist', 'heat', 'terrain'],
#  ['say', 'story', 'describes', 'hills', 'go', 'herendous', 'heat', 'beating'],
#  ['heat',
#   'also',
#   'makes',
#   'hard',
#   'makes',
#   'drink',
#   'throughout',
#   'story',
#   'trying',
#   'find',
#   'water',
#   'water',
#   'find',
#   'two',
#   'hundred',
#   'degrees',
#   'tasted',
#   'like',
#   'battery',
#   'acid',
#   'water',
#   'makes',
#   'hard',
#   'bicycle',
#   'far',
#   'distance',
#   'much',
#   'heat'],
#  ['al',
#   'smith',
#   'builders',
#   'empire',
#   'state',
#   'building',
#   'faced',
#   'several',
#   'obstacles',
#   'trying',
#   'allow',
#   'dirigibles',
#   'dock'],
#  ['first',
#   'obstacle',
#   'designing',
#   'strengthening',
#   'beams',
#   'frame',
#   'foundation',
#   'support',
#   'extra',
#   'stress',
#   'caused',
#   'dirigible',
#   'load',
#   'wind',
#   'pressure'],
#  ['second', 'gases', 'used', 'dirigibles', 'unsafe'],
#  ['dirigibles',
#   'outside',
#   'united',
#   'states',
#   'used',
#   'hydrogen',
#   'rather',
#   'helium',
#   'hydrogen',
#   'highly',
#   'flammable',
#   'l',
#   'sted',
#   'num'],
#  ['inefficient',
#   'gases',
#   'violent',
#   'air',
#   'currents',
#   'would',
#   'either',
#   'cause',
#   'dirigible',
#   'spend',
#   'add',
#   'lead',
#   'weights',
#   'would',
#   'dangling',
#   'high',
#   'pedestrians',
#   'l',
#   'sted',
#   'num'],
#  ['among',
#   'problems',
#   'existing',
#   'law',
#   'airships',
#   'flying',
#   'low',
#   'urban',
#   'areas',
#   'l',
#   'sted',
#   'num'],
#  ['therefore', 'unsafe', 'impractical', 'illegal'],
#  ['library'],
#  ['library', 'place', 'go', 'books', 'movies', 'music', 'magazines', 'etc'],
#  ['things', 'person', 'research', 'use', 'entertainment'],
#  ['censorship', 'libraries'],
#  ['opinion', 'caps', 'censorship', 'library'],
#  ['complaint',
#   'offended',
#   'something',
#   'library',
#   'removed',
#   'shelf',
#   'would',
#   'nothing',
#   'left',
#   'use',
#   'library'],
#  ['many',
#   'people',
#   'like',
#   'go',
#   'library',
#   'relax',
#   'good',
#   'peace',
#   'quiet',
#   'time',
#   'library',
#   'let',
#   'minds',
#   'flow',
#   'imaginate',
#   'dream'],
#  ['worry', 'offended', 'caps', 'caps', 'book'],
#  ['however', 'censorship', 'library', 'good', 'thing', 'used', 'delicately'],
#  ['example',
#   'moving',
#   'grown',
#   'books',
#   'section',
#   'children',
#   'read',
#   'nightmares',
#   'picture',
#   'saw'],
#  ['trying', 'say', 'censorship', 'library', 'low', 'standard'],
#  ['library',
#   'high',
#   'censorship',
#   'everything',
#   'taken',
#   'shelf',
#   'point',
#   'going',
#   'library',
#   'would',
#   'empty',
#   'room'],
#  ['someone',
#   'offended',
#   'something',
#   'library',
#   'depending',
#   'severe',
#   'offended',
#   'take',
#   'appropiate',
#   'measures'],
#  ['instance',
#   'something',
#   'offended',
#   'someone',
#   'unintentionaly',
#   'leave',
#   'something',
#   'offends',
#   'someone',
#   'intentionaly',
#   'race',
#   'ethnicity',
#   'something',
#   'like',
#   'would',
#   'appropriate',
#   'take',
#   'shelf'],
#  ['low',
#   'censorship',
#   'libraries',
#   'would',
#   'good',
#   'would',
#   'good',
#   'quantity',
#   'stuff',
#   'research',
#   'would',
#   'topics',
#   'choose',
#   'let',
#   'imagination',
#   'soar'],
#  ['time', 'would', 'worry', 'severely', 'offended'],
#  ['cyclist', 'affected', 'features', 'setting', 'lot'],
#  ['example', 'dry', 'hot', 'place', 'makes', 'thirsty'],
#  ['ghost', 'towns', 'make', 'hard', 'get', 'supplies'],
#  ['also', 'bad', 'road', 'slowed'],
#  ['bad',
#   'roads',
#   'even',
#   'would',
#   'probably',
#   'hurt',
#   'bike',
#   'roads',
#   'also',
#   'would',
#   'make',
#   'work',
#   'harder'],
#  ['many',
#   'things',
#   'world',
#   'childeren',
#   'see',
#   'poisen',
#   'minds',
#   'others',
#   'whatever',
#   'age',
#   'month'],
#  ['things',
#   'people',
#   'see',
#   'days',
#   'bad',
#   'shouln',
#   'seen',
#   'anybody',
#   'age'],
#  ['things',
#   'disposed',
#   'minds',
#   'clean',
#   'minds',
#   'future',
#   'generations',
#   'clean',
#   'also'],
#  ['reason',
#   'think',
#   'one',
#   'age',
#   'think',
#   'bad',
#   'things',
#   'kids',
#   'know',
#   'kid',
#   'grown',
#   'know',
#   'thing'],
#  ['things',
#   'like',
#   'libraries',
#   'thenthe',
#   'question',
#   'charge',
#   'deciding',
#   'right',
#   'wroung'],
#  ['sence',
#   'worlds',
#   'population',
#   'large',
#   'many',
#   'people',
#   'diferent',
#   'ideas',
#   'could',
#   'get',
#   'one',
#   'person',
#   'look',
#   'things',
#   'decide',
#   'good',
#   'bad'],
#  ['well', 'awnser', 'would', 'impossible'],
#  ['head', 'family', 'decide', 'crisis'],
#  ['welcome', 'date'],
#  ['day', 'age', 'numerous', 'advances', 'technology', 'made', 'everyday'],
#  ['one', 'advance', 'stood', 'rest', 'invention', 'computer'],
#  ['one',
#   'invention',
#   'computer',
#   'many',
#   'capabilities',
#   'caps',
#   'access',
#   'educational',
#   'purposes',
#   'keeping',
#   'people',
#   'touch',
#   'opening',
#   'people',
#   'new',
#   'aspects',
#   'life'],
#  ['computer', 'helped', 'mankind', 'various', 'discoveries', 'world'],
#  ['far',
#   'many',
#   'see',
#   'piece',
#   'technology',
#   'positive',
#   'effects',
#   'people',
#   'everywhere',
#   'everyday'],
#  ['new',
#   'trend',
#   'schools',
#   'around',
#   'globe',
#   'addition',
#   'computers',
#   'computer',
#   'lab'],
#  ['reason', 'technology', 'takes', 'learning', 'places', 'never', 'gone'],
#  ['whether',
#   'student',
#   'write',
#   'essay',
#   'presidency',
#   'person',
#   'obtain',
#   'background',
#   'information',
#   'science',
#   'experiment',
#   'paper',
#   'towel',
#   'also',
#   'bency',
#   'computer',
#   'aid',
#   'finding',
#   'information',
#   'need'],
#  ['programs',
#   'like',
#   'organization',
#   'allow',
#   'caps',
#   'present',
#   'work',
#   'new',
#   'efficient',
#   'way'],
#  ['children',
#   'school',
#   'adults',
#   'want',
#   'college',
#   'education',
#   'computers',
#   'let',
#   'learn',
#   'need',
#   'online',
#   'schools'],
#  ['also', 'important', 'caps', 'keep', 'touch', 'friends', 'school', 'hours'],
#  ['computers', 'able', 'help'],
#  ['many', 'times', 'said', 'communication', 'key', 'healthy', 'relationship'],
#  ['computers',
#   'believe',
#   'easy',
#   'way',
#   'maintain',
#   'contact',
#   'far',
#   'away',
#   'people'],
#  ['friends', 'family', 'keep', 'touch', 'completely', 'computer'],
#  ['live', 'close', 'enough', 'visit', 'daily'],
#  ['one',
#   'cautious',
#   'uses',
#   'internet',
#   'safety',
#   'techniques',
#   'make',
#   'new',
#   'friends',
#   'common',
#   'interests',
#   'computers'],
#  ['contact',
#   'new',
#   'people',
#   'one',
#   'way',
#   'computer',
#   'croaden',
#   'one',
#   'horizons'],
#  ['computers', 'like', 'keys', 'open', 'doors', 'new', 'places', 'ideas'],
#  ['use',
#   'technology',
#   'old',
#   'people',
#   'discovering',
#   'many',
#   'new',
#   'things',
#   'never',
#   'known'],
#  ['computers',
#   'help',
#   'open',
#   'people',
#   'unique',
#   'genres',
#   'music',
#   'never',
#   'listened'],
#  ['internet',
#   'many',
#   'video',
#   'tutorials',
#   'teach',
#   'people',
#   'different',
#   'skills',
#   'free'],
#  ['one',
#   'spare',
#   'time',
#   'could',
#   'use',
#   'computer',
#   'research',
#   'people',
#   'location',
#   'pyramids',
#   'location'],
#  ['way', 'computer', 'used', 'potential', 'positive', 'effect', 'someone'],
#  ['date', 'computer', 'essential', 'evey', 'day', 'life'],
#  ['imperative', 'decide', 'whether', 'remarkable', 'pece', 'technology'],
#  ['astounding', 'could', 'learn', 'hopping', 'computer'],
#  ['especially',
#   'keep',
#   'mind',
#   'computers',
#   'entertainment',
#   'education',
#   'well'],
#  ['waiting'],
#  ['discover', 'great', 'impact', 'computers', 'life', 'click', 'mouse'],
#  ['author', 'think', 'setting', 'means', 'getting', 'closer', 'destination'],
#  ['however', 'found', 'still', 'people', 'around'],
#  ['paniced', 'thought', 'going', 'die'],
#  ['places', 'desserted', 'thought', 'lead', 'nowhere'],
#  ['little',
#   'scared',
#   'fact',
#   'might',
#   'die',
#   'everything',
#   'around',
#   'sense',
#   'dead'],
#  ['patience',
#   'person',
#   'like',
#   'sit',
#   'sit',
#   'five',
#   'minutes',
#   'one',
#   'time',
#   'patience',
#   'bet',
#   'alse',
#   'right',
#   'riding',
#   'bike',
#   'training',
#   'wheels'],
#  ['five',
#   'learned',
#   'ride',
#   'bike',
#   'keeped',
#   'falling',
#   'one',
#   'piont',
#   'bike',
#   'flip',
#   'allmost',
#   'broke',
#   'jaw'],
#  ['finally',
#   'num',
#   'weeks',
#   'onstint',
#   'falling',
#   'rode',
#   'num',
#   'minutes',
#   'without',
#   'falling',
#   'finally',
#   'learn',
#   'riken',
#   'bike'],
#  ['day', 'fun', 'one'],
#  ['heard', 'really', 'bad', 'news'],
#  ['none', 'us', 'even', 'close', 'smiling'],
#  ['none', 'us'],
#  ['even', 'people', 'always', 'see', 'smiling', 'serious', 'look', 'face'],
#  ['bad', 'day'],
#  ['one',
#   'friends',
#   'person',
#   'great',
#   'idea',
#   'going',
#   'online',
#   'find',
#   'something',
#   'cheer',
#   'us'],
#  ['truly', 'amazing', 'idea'],
#  ['spent',
#   'hours',
#   'computer',
#   'sitting',
#   'looking',
#   'ridiculous',
#   'videos',
#   'knew'],
#  ['trying', 'make', 'laugh'],
#  ['day', 'started', 'bit', 'better'],
#  ['went', 'back', 'bit', 'people', 'left', 'go', 'home'],
#  ['three', 'us', 'still', 'location', 'house'],
#  ['person',
#   'person',
#   'sitting',
#   'watching',
#   'location',
#   'show',
#   'loved',
#   'came'],
#  ['psych'],
#  ['new', 'episode'],
#  ['great', 'day', 'turned'],
#  ['show', 'full', 'really', 'puny', 'dumb', 'humor', 'fit', 'three', 'us'],
#  ['person'],
#  ['laughing', 'good', 'time'],
#  ['person', 'laughing', 'show'],
#  ['asked', 'funny'],
#  ['kept', 'laughing'],
#  ['five', 'minuets', 'laughing'],
#  ['finally', 'stopped', 'asked'],
#  ['darn', 'funny'],
#  ['told', 'us'],
#  ['laughing', 'laugh'],
#  ['sound', 'really', 'weird'],
#  ['started', 'laughing'],
#  ['could', 'laughing', 'laugh'],
#  ['soon', 'realized', 'hard', 'stop'],
#  ['turned', 'okay', 'day', 'happened'],
#  ['ever', 'bad', 'day'],
#  ['bring', 'day', 'laughed', 'selves', 'ten', 'minuets'],
#  ['day', 'better'],
#  ['obstacles',
#   'facing',
#   'builders',
#   'add',
#   'mooring',
#   'mast',
#   'would',
#   'strengthen',
#   'building',
#   'integrity'],
#  ['necessary',
#   'mast',
#   'goes',
#   'wind',
#   'pressure',
#   'would',
#   'transmitted',
#   'way',
#   'foundation'],
#  ['floors',
#   'would',
#   'added',
#   'house',
#   'elevators',
#   'stairs',
#   'ticket',
#   'laggage',
#   'area'],
#  ['find',
#   'way',
#   'attach',
#   'mooring',
#   'mast',
#   'foundation',
#   'nearly',
#   'num',
#   'feet'],
#  ['obstacles', 'builder', 'empire', 'state', 'building', 'faced'],
#  ['planning', 'build', 'mask', 'dirigibles'],
#  ['first',
#   'tried',
#   'build',
#   'figured',
#   'structure',
#   'empire',
#   'state',
#   'building',
#   'could',
#   'hold',
#   'mask'],
#  ['empire', 'state', 'building', 'souport', 'mask', 'dirigibles'],
#  ['end', 'story', 'figured', 'way'],
#  ['one', 'obsticals'],
#  ['num',
#   'years',
#   'old',
#   'mother',
#   'sister',
#   'working',
#   'cleaning',
#   'around',
#   'house',
#   'kept',
#   'asking',
#   'caps',
#   'go',
#   'get',
#   'pizza',
#   'caps',
#   'every',
#   'time',
#   'asked',
#   'would',
#   'reply',
#   'help',
#   'us',
#   'finish',
#   'dinner',
#   'go',
#   'get',
#   'pizza'],
#  ['want', 'wash', 'windows', 'clean', 'room', 'wash', 'car'],
#  ['waited',
#   'playground',
#   'back',
#   'yard',
#   'swinging',
#   'going',
#   'slide',
#   'caps',
#   'num',
#   'minutes',
#   'got',
#   'boring'],
#  ['thats', 'knew', 'would', 'patient'],
#  ['ran', 'hill', 'river', 'waded', 'cold', 'water'],
#  ['caps', 'still', 'bored'],
#  ['got', 'river', 'ran', 'caps'],
#  ['caps', 'person', 'done', 'yet', 'asked'],
#  ['done', 'house', 'caps', 'car', 'yet', 'washed', 'answered'],
#  ['walk', 'bike', 'got', 'helmet', 'sitting', 'bike', 'seat'],
#  ['wind',
#   'face',
#   'nothing',
#   'compared',
#   'eating',
#   'pizza',
#   'caps',
#   'somehow',
#   'driving',
#   'drive',
#   'way',
#   'entertaining',
#   'cleaning'],
#  ['hop',
#   'bicycle',
#   'ran',
#   'house',
#   'taking',
#   'two',
#   'immediate',
#   'lefts',
#   'entering',
#   'house',
#   'look',
#   'clock',
#   'num',
#   'said'],
#  ['family',
#   'always',
#   'dinner',
#   'num',
#   'dad',
#   'gets',
#   'home',
#   'work',
#   'time',
#   'cooks',
#   'dinner'],
#  ['rush', 'see', 'caps', 'sister', 'done', 'yet', 'done', 'asked', 'rudely'],
#  ['could', 'help', 'want', 'faster', 'caps', 'answers'],
#  ['caps',
#   'fine',
#   'help',
#   'grab',
#   'hose',
#   'spray',
#   'dirt',
#   'bird',
#   'poop',
#   'windows'],
#  ['num',
#   'minutes',
#   'cleaning',
#   'done',
#   'caps',
#   'left',
#   'dad',
#   'note',
#   'said',
#   'lets',
#   'caps',
#   'whole',
#   'day',
#   'waitd',
#   'num',
#   'hours',
#   'caps',
#   'sister',
#   'finish',
#   'caps',
#   'end',
#   'finished',
#   'job'],
#  ['onece', 'family', 'went', 'location', 'patient'],
#  ['water', 'ride', 'get', 'log', 'sit', 'takes', 'hill'],
#  ['wait', 'get', 'top', 'splash', 'hill'],
#  ['well', 'one', 'everyones', 'favorite', 'rides', 'long', 'line'],
#  ['wait', 'half', 'hour', 'ride'],
#  ['order', 'something', 'takes', 'time', 'must', 'patient'],
#  ['patient', 'probably', 'want', 'get', 'wanted'],
#  ['one',
#   'day',
#   'person',
#   'mom',
#   'caps',
#   'decited',
#   'go',
#   'shoping',
#   'person',
#   'despretly',
#   'wanted',
#   'go'],
#  ['mom', 'kept', 'saying', 'caps'],
#  ['person',
#   'begged',
#   'begged',
#   'mom',
#   'finally',
#   'said',
#   'caps',
#   'cant',
#   'complain',
#   'person',
#   'went',
#   'shoping',
#   'mom'],
#  ['person', 'mom', 'arrived', 'store'],
#  ['date', 'person', 'said'],
#  ['board', 'go', 'mom', 'caps', 'caps', 'patient'],
#  ['person',
#   'said',
#   'patient',
#   'want',
#   'patient',
#   'weve',
#   'like',
#   'date',
#   'hours',
#   'ten',
#   'date'],
#  ['caps', 'patients', 'said', 'person'],
#  ['mom',
#   'made',
#   'deal',
#   'person',
#   'good',
#   'num',
#   'date',
#   'go',
#   'ice',
#   'cream',
#   'place'],
#  ['next',
#   'num',
#   'date',
#   'made',
#   'mom',
#   'go',
#   'crazy',
#   'every',
#   'second',
#   'person',
#   'saying',
#   'board',
#   'go',
#   'hurry'],
#  ['finally', 'person', 'mom', 'left'],
#  ['got',
#   'car',
#   'drove',
#   'right',
#   'past',
#   'ice',
#   'cream',
#   'place',
#   'person',
#   'said',
#   'wait',
#   'past',
#   'mom',
#   'said',
#   'know'],
#  ['person', 'said', 'made', 'deal', 'remember'],
#  ['mom', 'said', 'yup', 'broke', 'deal', 'learn'],
#  ['person',
#   'said',
#   'make',
#   'deal',
#   'sign',
#   'contract',
#   'mom',
#   'said',
#   'caps',
#   'patients',
#   'virtue',
#   'need',
#   'learn'],
#  ['story', 'patients', 'way'],
#  ['think',
#   'author',
#   'ends',
#   'story',
#   'paragraph',
#   'story',
#   'also',
#   'say',
#   'saeng',
#   'would',
#   'try',
#   'test'],
#  ['story',
#   'says',
#   'realised',
#   'many',
#   'thing',
#   'thought',
#   'strange',
#   'become',
#   'though',
#   'quiet',
#   'repetition',
#   'season',
#   'opon',
#   'reason',
#   'almost',
#   'familiar',
#   'last',
#   'paragraph',
#   'help',
#   'bring',
#   'together'],
#  ['one', 'caps', 'patient', 'flight', 'got', 'caps'],
#  ['going', 'location', 'caps', 'sudden', 'caps', 'sign', 'came', 'caps'],
#  ['kind', 'sud', 'said', 'patient'],
#  ['flight'],
#  ['caps'],
#  ['waiting', 'lot', 'things'],
#  ['first', 'went', 'ear', 'food', 'court'],
#  ['delceced', 'go', 'chile'],
#  ['also', 'wait', 'food'],
#  ['got', 'good', 'hach', 'good'],
#  ['went', 'caps', 'caps'],
#  ['caps', 'caps', 'got', 'num', 'key', 'chains', 'friends'],
#  ['got', 'num', 'magizens', 'reading', 'caps'],
#  ['also', 'get', 'caps', 'caps'],
#  ['good'],
#  ['next', 'took', 'little', 'walk', 'around', 'caps'],
#  ['went', 'sat', 'relaxed', 'couple', 'caps'],
#  ['fell', 'asleep'],
#  ['woke', 'caps', 'board'],
#  ['caps', 'finally', 'get', 'location', 'enjoy', 'caps', 'weather'],
#  ['learned', 'patient', 'really', 'matter'],
#  ['time', 'really', 'patient'],
#  ['author',
#   'probably',
#   'ends',
#   'story',
#   'like',
#   'creates',
#   'sense',
#   'hope',
#   'wonder'],
#  ['feel', 'story', 'essentially', 'coming', 'things'],
#  ['example', 'saeng', 'driving', 'test', 'failed'],
#  ['also', 'seemed', 'bit', 'overwhelmed', 'thought', 'home'],
#  ['saeng',
#   'obviously',
#   'cares',
#   'failing',
#   'test',
#   'put',
#   'time',
#   'thinking',
#   'led',
#   'green',
#   'house'],
#  ['green', 'house', 'looking', 'specific', 'plant', 'buy', 'reminded', 'home'],
#  ['thinking', 'home', 'grandmother', 'upsets'],
#  ['saeng',
#   'almost',
#   'internal',
#   'war',
#   'self',
#   'author',
#   'ends',
#   'story',
#   'way',
#   'end',
#   'story',
#   'giving',
#   'reader',
#   'sense',
#   'hope',
#   'saeng',
#   'wonder'],
#  ['caps',
#   'home',
#   'blueprints',
#   'lives',
#   'person',
#   'creates',
#   'distinct',
#   'mood'],
#  ['think', 'mood', 'caps', 'warm', 'caring', 'comforting', 'loving'],
#  ['author', 'home', 'family', 'oriented', 'blood', 'family'],
#  ['neighborhood', 'family', 'racism', 'norm', 'segrigation', 'prevailed'],
#  ['narciso',
#   'rodriguez',
#   'discribes',
#   'caps',
#   'sounds',
#   'comforting',
#   'loving'],
#  ['caps',
#   'parents',
#   'always',
#   'kept',
#   'arms',
#   'door',
#   'open',
#   'many',
#   'people',
#   'considered',
#   'family',
#   'knowing',
#   'would',
#   'us'],
#  ['brings',
#   'happy',
#   'light',
#   'feel',
#   'article',
#   'coforting',
#   'well',
#   'rodriguez',
#   'caps',
#   'always',
#   'grateful',
#   'parents',
#   'love',
#   'sacrifice',
#   'mood',
#   'changes',
#   'bit'],
#  ['admiring', 'grateful', 'compationate'],
#  ['narciso',
#   'rodriguez',
#   'discribes',
#   'parents',
#   'struggle',
#   'could',
#   'grow',
#   'caps',
#   'nicer',
#   'feel',
#   'hes',
#   'grateful',
#   'loving'],
#  ['mood',
#   'happy',
#   'loving',
#   'full',
#   'compasion',
#   'point',
#   'mood',
#   'created',
#   'caps',
#   'person',
#   'home',
#   'blueprints',
#   'lives'],
#  ['mood',
#   'set',
#   'excerpt',
#   'narciso',
#   'rodriguez',
#   'narciso',
#   'rodriguez',
#   'mood',
#   'created',
#   'author',
#   'reflect',
#   'life',
#   'relive',
#   'great',
#   'expierences',
#   'author',
#   'gone',
#   'mind'],
#  ['think', 'great', 'times', 'author', 'family'],
#  ['story',
#   'many',
#   'different',
#   'settings',
#   'affected',
#   'author',
#   'many',
#   'different',
#   'ways'],
#  ['beginning', 'journey', 'came', 'across', 'ghost', 'town'],
#  ['reacted', 'features', 'setting', 'humor', 'hope'],
#  ['chuckled', 'checked', 'water', 'supply', 'moved'],
#  ['still', 'hope', 'would', 'end', 'safe', 'right', 'place'],
#  ['next', 'setting', 'abandoned', 'shed', 'water', 'pump', 'fork', 'rode'],
#  ['grew', 'worried', 'saw', 'near', 'town', 'still', 'sight'],
#  ['sight',
#   'troubling',
#   'features',
#   'next',
#   'setting',
#   'caught',
#   'eye',
#   'desperate',
#   'devastated'],
#  ['point',
#   'tumble',
#   'weed',
#   'crossed',
#   'path',
#   'ridiculously',
#   'large',
#   'snake',
#   'rough',
#   'terrain',
#   'middle',
#   'desert',
#   'little',
#   'water',
#   'reached',
#   'abandoned',
#   'caps',
#   'factory',
#   'hope',
#   'lost',
#   'planning',
#   'death'],
#  ['going', 'die', 'birds', 'would', 'pick', 'clean'],
#  ['caps',
#   'reached',
#   'fish',
#   'camp',
#   'relieved',
#   'overwhelming',
#   'urge',
#   'seek',
#   'gary',
#   'wilber',
#   'kiss',
#   'buy',
#   'bait',
#   'overjoyed',
#   'overwhelmed',
#   'survived'],
#  ['caps', 'creates', 'mood', 'happiness', 'caps'],
#  ['states', 'memories', 'child', 'made', 'happy'],
#  ['mentions', 'love', 'cooking', 'parents'],
#  ['also', 'mentions', 'music', 'passionate', 'still', 'adores', 'even', 'day'],
#  ['also', 'describes', 'good', 'neighborhood', 'close', 'knit', 'community'],
#  ['startes',
#   'explain',
#   'lot',
#   'family',
#   'blood',
#   'related',
#   'included',
#   'people'],
#  ['explained', 'parents', 'self', 'sacrafising', 'people'],
#  ['good', 'mood', 'caps', 'wrote', 'caps'],
#  ['mood',
#   'created',
#   'author',
#   'narciso',
#   'rodriguez',
#   'memoir',
#   'grateful',
#   'appreciative',
#   'life',
#   'also',
#   'happy',
#   'life'],
#  ['memoir',
#   'think',
#   'realized',
#   'explaining',
#   'family',
#   'really',
#   'grateful',
#   'one'],
#  ['figure',
#   'read',
#   'states',
#   'growing',
#   'environment',
#   'instilled',
#   'great',
#   'sense',
#   'family',
#   'nothing',
#   'blood',
#   'relative'],
#  ['also',
#   'says',
#   'proves',
#   'mood',
#   'grateful',
#   'always',
#   'grateful',
#   'parents',
#   'love',
#   'sacrifice'],
#  ['caps', 'said', 'believe', 'thats', 'mood', 'memoir'],
#  ['author',
#   'concludes',
#   'story',
#   'come',
#   'back',
#   'saeng',
#   'wowed',
#   'silently',
#   'spring',
#   'snows',
#   'melt',
#   'geese',
#   'return',
#   'hibiscus',
#   'budding',
#   'take',
#   'test',
#   'wants',
#   'express',
#   'readers',
#   'willingly',
#   'determined',
#   'accomplish',
#   'failed'],
#  ['since',
#   'failed',
#   'test',
#   'first',
#   'time',
#   'wants',
#   'overcome',
#   'failure',
#   'succede',
#   'author',
#   'wants',
#   'look',
#   'determined',
#   'end'],
#  ['builders',
#   'go',
#   'many',
#   'obstacles',
#   'caps',
#   'allow',
#   'dirigible',
#   'dock',
#   'organization'],
#  ['first', 'thing', 'problem', 'geting', 'top', 'empire', 'state', 'building'],
#  ['said', 'wind', 'made', 'really', 'hard', 'get', 'dirigible', 'poping'],
#  ['also', 'safty'],
#  ['already', 'fire', 'another', 'dirigible', 'catching', 'fire'],
#  ['gases',
#   'inside',
#   'really',
#   'flamable',
#   'would',
#   'make',
#   'really',
#   'big',
#   'problem'],
#  ['last', 'thing', 'conider', 'airships', 'low'],
#  ['dirigible', 'would', 'pop'],
#  ['reason',
#   'concider',
#   'caps',
#   'allow',
#   'dirigible',
#   'empire',
#   'state',
#   'building'],
#  ['anyone',
#   'ever',
#   'rode',
#   'bike',
#   'knows',
#   'relaxing',
#   'truly',
#   'forced',
#   'ride',
#   'miles',
#   'miles',
#   'caps',
#   'terrain',
#   'without',
#   'water',
#   'relaxation',
#   'feels',
#   'like',
#   'oasis',
#   'caps',
#   'beat',
#   'roads',
#   'dryness',
#   'around',
#   'really',
#   'puts',
#   'domper',
#   'experience',
#   'caps',
#   'extends',
#   'need',
#   'thirst',
#   'enhancing',
#   'amount',
#   'dryness',
#   'air',
#   'amount',
#   'energy'],
#  ['ability',
#   'block',
#   'trying',
#   'focus',
#   'something',
#   'easier',
#   'handle',
#   'exactly',
#   'want',
#   'situations',
#   'caps',
#   'terrain',
#   'really',
#   'build',
#   'character',
#   'cyclist',
#   'adding',
#   'fact',
#   'amount',
#   'water',
#   'dryness',
#   'around',
#   'sounds',
#   'like',
#   'torture'],
#  ['hope', 'ever', 'become', 'cyclist', 'never', 'endure', 'kind', 'situation'],
#  ['dear', 'local', 'newspaper', 'caps', 'would', 'person', 'computer'],
#  ['well',
#   'think',
#   'nothing',
#   'caps',
#   'like',
#   'family',
#   'far',
#   'away',
#   'another',
#   'country',
#   'well',
#   'whith',
#   'computer',
#   'see',
#   'throught',
#   'camara',
#   'talk',
#   'like'],
#  ['computers',
#   'take',
#   'time',
#   'help',
#   'understand',
#   'menning',
#   'family',
#   'many',
#   'reasons',
#   'think',
#   'computers',
#   'important'],
#  ['first',
#   'reason',
#   'give',
#   'information',
#   'place',
#   'might',
#   'interested',
#   'see',
#   'know',
#   'culture'],
#  ['many',
#   'people',
#   'like',
#   'explore',
#   'see',
#   'new',
#   'places',
#   'maybe',
#   'time',
#   'might',
#   'much',
#   'work'],
#  ['exception', 'someone', 'put', 'oportunities', 'time', 'computer'],
#  ['second', 'reason', 'work'],
#  ['people',
#   'like',
#   'work',
#   'office',
#   'need',
#   'information',
#   'place',
#   'disaster',
#   'happened'],
#  ['might',
#   'need',
#   'somenthing',
#   'see',
#   'happen',
#   'caps',
#   'condition',
#   'happend'],
#  ['people',
#   'work',
#   'important',
#   'place',
#   'need',
#   'computer',
#   'saving',
#   'work',
#   'lose',
#   'get',
#   'fired'],
#  ['third', 'last', 'reason', 'organized'],
#  ['organized', 'important', 'helps', 'keep', 'job', 'everything', 'hand'],
#  ['well', 'computers', 'pass', 'time', 'also', 'makes', 'life', 'easier'],
#  ['many',
#   'people',
#   'say',
#   'caps',
#   'much',
#   'papers',
#   'computer',
#   'paper',
#   'one',
#   'page',
#   'saved',
#   'see'],
#  ['month', 'see', 'many', 'people', 'computers', 'use', 'productive', 'way'],
#  ['pass', 'time', 'like', 'people', 'say'],
#  ['also',
#   'helps',
#   'many',
#   'stuff',
#   'future',
#   'play',
#   'around',
#   'new',
#   'friends'],
#  ['well',
#   'month',
#   'see',
#   'three',
#   'main',
#   'reasons',
#   'keeping',
#   'computer',
#   'house',
#   'using',
#   'good',
#   'productive',
#   'way'],
#  ['dear', 'caps', 'ever', 'seen', 'offensive', 'book', 'shelf', 'library'],
#  ['would', 'want', 'children', 'influenced', 'findings'],
#  ['question', 'need', 'ask', 'certain', 'materials', 'appear', 'libraries'],
#  ['concerned',
#   'citizen',
#   'writing',
#   'relect',
#   'opinion',
#   'censorship',
#   'libraries'],
#  ['personal',
#   'experiences',
#   'come',
#   'across',
#   'magazines',
#   'books',
#   'music',
#   'offensive'],
#  ['believe', 'materials', 'found', 'libraries'],
#  ['many',
#   'people',
#   'still',
#   'would',
#   'want',
#   'materials',
#   'suggestion',
#   'seperate',
#   'room',
#   'offensive',
#   'materials'],
#  ['seperate', 'room', 'keep', 'materials', 'away', 'young', 'kids'],
#  ['get',
#   'older',
#   'children',
#   'believe',
#   'library',
#   'kid',
#   'friendly',
#   'place'],
#  ['order', 'make', 'happen', 'need', 'find', 'place', 'materials'],
#  ['libraries',
#   'need',
#   'somewhere',
#   'anyone',
#   'go',
#   'college',
#   'kid',
#   'trying',
#   'prepare',
#   'test',
#   'young',
#   'child',
#   'wanting',
#   'discover',
#   'person',
#   'old',
#   'man',
#   'wanting',
#   'enjoy',
#   'peace',
#   'quiet'],
#  ['distraction', 'offensive', 'materials', 'needed', 'library'],
#  ['libraries', 'places', 'learn', 'explore', 'different', 'sources', 'inside'],
#  ['young',
#   'children',
#   'fairytale',
#   'land',
#   'anything',
#   'possible',
#   'unimaginable',
#   'become',
#   'true'],
#  ['materials',
#   'adults',
#   'want',
#   'children',
#   'see',
#   'month',
#   'comfortable',
#   'child'],
#  ['libraries', 'need', 'kid', 'friendly', 'places', 'ages', 'enjoy', 'offer'],
#  ['see', 'offensive', 'materials', 'libraries'],
#  ['ages', 'able', 'enjoy', 'library', 'offer', 'materials', 'possible'],
#  ['please', 'consider', 'following'],
#  ['kind', 'regards', 'person'],
#  ['based',
#   'excerpt',
#   'mooring',
#   'mast',
#   'marcia',
#   'amidon',
#   'caps',
#   'builders',
#   'empire',
#   'state',
#   'building',
#   'faced',
#   'many',
#   'obstacles',
#   'attempting',
#   'allow',
#   'dirigibles',
#   'dock',
#   'safety',
#   'nature',
#   'legislation'],
#  ['first',
#   'would',
#   'difficult',
#   'safely',
#   'allow',
#   'foreign',
#   'dirigibles',
#   'dock'],
#  ['paragraph',
#   'num',
#   'says',
#   'dirigibles',
#   'outside',
#   'united',
#   'states',
#   'used',
#   'hydrogen',
#   'rather',
#   'helium',
#   'hydrogen',
#   'highly',
#   'flammable'],
#  ['displays', 'fire', 'therefore', 'safety', 'obstacle'],
#  ['next',
#   'air',
#   'currents',
#   'made',
#   'difficult',
#   'dirigibles',
#   'dock',
#   'safely'],
#  ['air',
#   'near',
#   'top',
#   'building',
#   'affected',
#   'air',
#   'currents',
#   'difficult',
#   'pilots',
#   'land'],
#  ['also',
#   'using',
#   'lead',
#   'weights',
#   'empire',
#   'state',
#   'building',
#   'would',
#   'dangling',
#   'high',
#   'pedestrians',
#   'street',
#   'neither',
#   'practical',
#   'safe'],
#  ['way', 'work', 'combat', 'uncertainty', 'wind', 'nature', 'obstacle'],
#  ['finally', 'laws', 'aircrafts', 'flying', 'close', 'city'],
#  ['paragraph',
#   'num',
#   'says',
#   'existing',
#   'law',
#   'airships',
#   'flying',
#   'low',
#   'urban',
#   'areas'],
#  ['law', 'would', 'make', 'illegal', 'ship', 'ever', 'tie', 'building'],
#  ['purpose',
#   'moor',
#   'would',
#   'illegal',
#   'would',
#   'nearly',
#   'impossible',
#   'dirigible',
#   'ever',
#   'tie',
#   'empire',
#   'state',
#   'building'],
#  ['builders',
#   'empire',
#   'state',
#   'building',
#   'faced',
#   'many',
#   'challenges',
#   'regarding',
#   'moor',
#   'opening',
#   'never',
#   'successful',
#   'result'],
#  ['mood', 'created', 'author', 'memoir', 'happy'],
#  ['symbolizes', 'togetherness', 'coming', 'together', 'family'],
#  ['passage', 'evry', 'one', 'caring', 'open', 'anyone', 'living'],
#  ['child', 'story', 'talks', 'abou', 'greatful', 'parints'],
#  ['happy', 'family', 'living', 'together', 'one'],
#  ['evry', 'one', 'exsepting', 'one', 'another'],
#  ['think', 'mood', 'happy'],
#  ['obstacles',
#   'builders',
#   'empire',
#   'state',
#   'builduing',
#   'faced',
#   'attempting',
#   'allow',
#   'dirigibles',
#   'dock',
#   'allow',
#   'dirigibles',
#   'anchor',
#   'several',
#   'hours',
#   'refueling',
#   'service',
#   'let',
#   'passengers'],
#  ['dirigibles',
#   'docked',
#   'means',
#   'electric',
#   'winch',
#   'hauled',
#   'line',
#   'front',
#   'ship',
#   'tied',
#   'mast'],
#  ['body',
#   'dirigibles',
#   'could',
#   'swing',
#   'breeze',
#   'yet',
#   'passengers',
#   'could',
#   'safely',
#   'get',
#   'dirigible',
#   'walking',
#   'gangplank',
#   'open',
#   'observation',
#   'platform'],
#  ['go', 'obstacles', 'order', 'build', 'empire', 'state', 'builduing'],
#  ['dear', 'caps', 'believe', 'computers', 'necessary'],
#  ['believe', 'help', 'us', 'learn', 'say', 'books'],
#  ['people',
#   'believe',
#   'caps',
#   'help',
#   'hand',
#   'eye',
#   'coordinated',
#   'playing',
#   'catch'],
#  ['believe',
#   'internet',
#   'teaches',
#   'people',
#   'faraway',
#   'places',
#   'say',
#   'visit',
#   'places',
#   'know',
#   'typed',
#   'computer'],
#  ['caps',
#   'computers',
#   'books',
#   'definetly',
#   'would',
#   'conqure',
#   'whomever',
#   'roots',
#   'books'],
#  ['good', 'book', 'healthy'],
#  ['reading',
#   'book',
#   'computer',
#   'one',
#   'two',
#   'things',
#   'unhealthy',
#   'unethnical'],
#  ['read',
#   'book',
#   'computer',
#   'even',
#   'caps',
#   'could',
#   'fun',
#   'turning',
#   'pages',
#   'beautiful',
#   'paperback',
#   'hard',
#   'covered',
#   'book'],
#  ['believe', 'learn', 'much', 'read', 'book', 'real', 'book'],
#  ['type',
#   'computer',
#   'clickety',
#   'clickety',
#   'say',
#   'learning',
#   'learn',
#   'type',
#   'without',
#   'looking',
#   'hand',
#   'eye',
#   'coordination'],
#  ['say'],
#  ['natural'],
#  ['go', 'side', 'throw', 'ball', 'one', 'another'],
#  ['real', 'way', 'show', 'hand', 'eye', 'coordination'],
#  ['fun', 'game', 'easy', 'plus', 'teaches', 'hand', 'eye', 'coordination'],
#  ['want',
#   'surf',
#   'web',
#   'find',
#   'nice',
#   'vacation',
#   'spot',
#   'really',
#   'visit',
#   'place'],
#  ['flip',
#   'coin',
#   'heads',
#   'location',
#   'tails',
#   'location',
#   'caps',
#   'pick',
#   'heads',
#   'stop',
#   'surfing',
#   'web',
#   'get',
#   'info',
#   'place'],
#  ['go', 'fly', 'surf', 'totaly', 'radical', 'waves'],
#  ['surf', 'real', 'waves', 'next', 'artificial', 'ones', 'dudes'],
#  ['restate',
#   'computers',
#   'might',
#   'seem',
#   'okay',
#   'guess',
#   'bad',
#   'cup',
#   'coffee'],
#  ['take',
#   'time',
#   'away',
#   'computer',
#   'go',
#   'read',
#   'book',
#   'play',
#   'game',
#   'catch'],
#  ['know', 'hows', 'trip', 'location', 'location', 'location'],
#  ['knows', 'definetly', 'experience', 'sure'],
#  ['author', 'gratefull'],
#  ['parents', 'moved', 'america'],
#  ['could', 'good', 'education'],
#  ['thank', 'parents', 'enough', 'moving'],
#  ['tells', 'much', 'courage', 'thanks', 'much', 'leaving', 'jobs'],
#  ['also', 'talks', 'home'],
#  ['home', 'place', 'learn', 'love', 'admire', 'relatives'],
#  ['even', 'matter', 'blood', 'related'],
#  ['love', 'either', 'way'],
#  ['lot',
#   'people',
#   'patient',
#   'wait',
#   'want',
#   'make',
#   'someone',
#   'mad',
#   'mess',
#   'something'],
#  ['people', 'always', 'careful'],
#  ['ever', 'patient', 'sometimes', 'hard', 'patient', 'pretty', 'easy'],
#  ['everyone', 'absouletly', 'knows', 'people', 'know', 'trust'],
#  ['many',
#   'different',
#   'things',
#   'patient',
#   'know',
#   'one',
#   'choose',
#   'write',
#   'cause',
#   'alot'],
#  ['caps',
#   'someone',
#   'bathroom',
#   'wait',
#   'patiently',
#   'caps',
#   'hold',
#   'keep',
#   'knocking',
#   'door',
#   'use',
#   'one',
#   'caps',
#   'someone',
#   'computer',
#   'wait',
#   'turn',
#   'caps',
#   'pass',
#   'hour',
#   'tell',
#   'person',
#   'get',
#   'mean',
#   'either',
#   'need',
#   'turn'],
#  ['way', 'patient', 'leat', 'num', 'num', 'minutes'],
#  ['hard'],
#  ['pretty', 'easy', 'everyone', 'knows', 'know'],
#  ['excerpt',
#   'mooring',
#   'mast',
#   'organization',
#   'builders',
#   'empire',
#   'state',
#   'building',
#   'faced',
#   'obstacles',
#   'attempting',
#   'allow',
#   'dirigibles',
#   'dock',
#   'although',
#   'sounded',
#   'like',
#   'great',
#   'idea',
#   'seemed',
#   'possible',
#   'first'],
#  ['idea',
#   'mooring',
#   'mast',
#   'caps',
#   'state',
#   'building',
#   'neither',
#   'practical',
#   'safe'],
#  ['paragraph', 'fourteen', 'marcia', 'states', 'dirigible', 'idea', 'safe'],
#  ['winds',
#   'top',
#   'building',
#   'constantly',
#   'shifting',
#   'due',
#   'violent',
#   'air',
#   'currents'],
#  ['last',
#   'sentence',
#   'paragraph',
#   'fourteen',
#   'author',
#   'states',
#   'another',
#   'reason',
#   'idea',
#   'wasnt',
#   'safe',
#   'practical'],
#  ['would', 'dangling', 'high', 'pedestrians', 'street'],
#  ['mood',
#   'created',
#   'caps',
#   'memoir',
#   'shows',
#   'grateful',
#   'home',
#   'live',
#   'born',
#   'parents'],
#  ['happy', 'live', 'family', 'unity', 'friendship', 'others'],
#  ['learned',
#   'definition',
#   'family',
#   'know',
#   'family',
#   'like',
#   'respects',
#   'family',
#   'great',
#   'home',
#   'location'],
#  ['caps',
#   'learned',
#   'love',
#   'forgeting',
#   'family',
#   'bring',
#   'simple',
#   'house',
#   'home',
#   'said',
#   'last',
#   'paragraph'],
#  ['happy', 'home', 'stay', 'finding', 'new', 'life', 'ahead'],
#  ['greatful', 'love', 'sacarfice', 'parents'],
#  ['home', 'sweet'],
#  ['think',
#   'certain',
#   'materials',
#   'books',
#   'music',
#   'movies',
#   'magazines',
#   'etc',
#   'removed',
#   'shelves',
#   'found',
#   'offensive'],
#  ['people',
#   'enjoy',
#   'books',
#   'offensive',
#   'language',
#   'content',
#   'people',
#   'love',
#   'feel',
#   'engery',
#   'tone',
#   'writer'],
#  ['personal',
#   'love',
#   'offensive',
#   'langauge',
#   'everything',
#   'censored',
#   'would',
#   'feel',
#   'like',
#   'everything',
#   'dull',
#   'fake'],
#  ['caps', 'cheating', 'caps', 'caps', 'feel', 'wow', 'body'],
#  ['look',
#   'censor',
#   'cheating',
#   'person',
#   'felt',
#   'dull',
#   'got',
#   'cheated',
#   'probably',
#   'thought',
#   'ten',
#   'different',
#   'thing',
#   'would',
#   'said',
#   'differently',
#   'uncensored'],
#  ['parent',
#   'want',
#   'child',
#   'reading',
#   'seeing',
#   'try',
#   'teach',
#   'keep',
#   'child',
#   'away'],
#  ['instead', 'removing', 'move', 'num', 'section', 'library'],
#  ['num',
#   'section',
#   'warn',
#   'kids',
#   'parent',
#   'getting',
#   'parent',
#   'want',
#   'exposed',
#   'reality',
#   'means',
#   'area'],
#  ['libraries',
#   'usually',
#   'divided',
#   'section',
#   'ask',
#   'local',
#   'libraries',
#   'divide',
#   'adult',
#   'children',
#   'books',
#   'section',
#   'libraries',
#   'tell'],
#  ['views',
#   'censorship',
#   'libraries',
#   'definitely',
#   'varies',
#   'person',
#   'person'],
#  ['offended',
#   'material',
#   'anyone',
#   'access',
#   'want',
#   'right',
#   'read',
#   'listen',
#   'watch',
#   'whatever',
#   'choose'],
#  ['believe',
#   'pros',
#   'cons',
#   'choice',
#   'either',
#   'way',
#   'look',
#   'need',
#   'sort',
#   'censorship',
#   'libraries',
#   'line',
#   'must',
#   'drawn',
#   'somewhere'],
#  ['lyrics', 'music', 'come', 'extremely', 'offensive', 'people'],
#  ['inappropriate',
#   'scenes',
#   'movies',
#   'whether',
#   'involving',
#   'two',
#   'people',
#   'opposite',
#   'sex',
#   'intense',
#   'action',
#   'moments',
#   'something',
#   'people',
#   'young',
#   'age',
#   'exposed'],
#  ['easy', 'access', 'library', 'part', 'problem'],
#  ['someone', 'age', 'get', 'hands', 'anything', 'want'],
#  ['experience', 'opportunity', 'get', 'whatever', 'wanted', 'library'],
#  ['advertising',
#   'pictures',
#   'cover',
#   'books',
#   'movies',
#   'magazines',
#   'etc',
#   'gave',
#   'false',
#   'sense',
#   'material',
#   'really',
#   'contained',
#   'younger'],
#  ['came', 'home', 'day', 'library', 'materials', 'parents', 'approve'],
#  ['look',
#   'point',
#   'view',
#   'would',
#   'probably',
#   'thinking',
#   'got',
#   'rid',
#   'material',
#   'someone',
#   'would',
#   'find',
#   'offensive',
#   'libraries',
#   'would',
#   'left',
#   'close',
#   'nothing'],
#  ['reality',
#   'believe',
#   'people',
#   'realized',
#   'exposure',
#   'kind',
#   'material',
#   'offensive',
#   'authors',
#   'would',
#   'change',
#   'way',
#   'would',
#   'write',
#   'directors',
#   'would',
#   'change',
#   'way',
#   'produced',
#   'movies',
#   'artists',
#   'would',
#   'change',
#   'lyrics',
#   'songs'],
#  ['yes',
#   'library',
#   'shelves',
#   'would',
#   'rid',
#   'many',
#   'materials',
#   'would',
#   'replaced',
#   'people',
#   'want'],
#  ['others',
#   'might',
#   'argue',
#   'right',
#   'read',
#   'listen',
#   'watch',
#   'would',
#   'like'],
#  ['month',
#   'true',
#   'others',
#   'right',
#   'let',
#   'children',
#   'go',
#   'libraries',
#   'without',
#   'worrying',
#   'gruesome',
#   'material',
#   'might',
#   'exposed'],
#  ['although',
#   'people',
#   'argument',
#   'month',
#   'go',
#   'either',
#   'way',
#   'line',
#   'never',
#   'drawn',
#   'available',
#   'knows',
#   'world',
#   'month',
#   'come'],
#  ['material',
#   'get',
#   'offensive',
#   'disturbing',
#   'leave',
#   'bigger',
#   'effect',
#   'minds',
#   'people'],
#  ['children',
#   'exposed',
#   'evils',
#   'world',
#   'even',
#   'younger',
#   'age',
#   'ever',
#   'know',
#   'realize',
#   'else',
#   'world',
#   'offer'],
#  ['authors',
#   'directors',
#   'producers',
#   'artists',
#   'change',
#   'material',
#   'show',
#   'want'],
#  ['think', 'computers', 'good', 'effect', 'people'],
#  ['people', 'computer', 'long'],
#  ['also',
#   'think',
#   'computers',
#   'good',
#   'effect',
#   'people',
#   'new',
#   'technology'],
#  ['computers', 'positive', 'help', 'stuck', 'need', 'look', 'something'],
#  ['computers', 'positive'],
#  ['people', 'go', 'computer', 'ther', 'num', 'hours', 'straight'],
#  ['sure',
#   'might',
#   'num',
#   'hours',
#   'day',
#   'stuff',
#   'like',
#   'school',
#   'meals',
#   'activities'],
#  ['people', 'need', 'computers', 'caps'],
#  ['news',
#   'caps',
#   'companies',
#   'need',
#   'computers',
#   'editing',
#   'printing',
#   'papaer'],
#  ['also', 'put', 'news', 'website'],
#  ['would', 'people', 'without', 'computer'],
#  ['computers', 'positive', 'new', 'technology'],
#  ['new', 'technology', 'helping', 'people', 'interact'],
#  ['long', 'distance', 'friend', 'family', 'member', 'many', 'ways', 'talk'],
#  ['could', 'use', 'caps', 'skype', 'oovoo', 'caps', 'even', 'email'],
#  ['go', 'computer', 'dont', 'sit', 'watch', 'caps', 'caps', 'caps', 'online'],
#  ['interact', 'friends', 'percent', 'us', 'population', 'ages', 'num', 'caps'],
#  ['percent', 'skype', 'oovoo', 'talk', 'people', 'far', 'away', 'visit'],
#  ['computers',
#   'positive',
#   'help',
#   'school',
#   'know',
#   'go',
#   'internet',
#   'look',
#   'need',
#   'translate',
#   'caps',
#   'caps',
#   'go',
#   'computer',
#   'translate'],
#  ['percent', 'people', 'learned', 'dictionary', 'using', 'internet'],
#  ['word', 'want', 'know', 'dictionary', 'look', 'online'],
#  ['computers', 'positive', 'effect', 'people'],
#  ['nobody',
#   'spends',
#   'much',
#   'time',
#   'computer',
#   'go',
#   'outside',
#   'hang',
#   'friends'],
#  ['people',
#   'actually',
#   'need',
#   'computer',
#   'caps',
#   'new',
#   'technology',
#   'coming',
#   'letting',
#   'people',
#   'interact',
#   'people',
#   'across',
#   'world'],
#  ['positve', 'school', 'work', 'definitions', 'even', 'translation'],
#  ['computers', 'negative', 'dont', 'take', 'away', 'life'],
#  ['tons',
#   'books',
#   'library',
#   'people',
#   'month',
#   'find',
#   'offensive',
#   'young',
#   'readers',
#   'today'],
#  ['think', 'materials', 'removed', 'shelves'],
#  ['people', 'right', 'read', 'choose', 'read'],
#  ['many', 'reasons', 'think', 'materials', 'removed', 'library'],
#  ['first', 'many', 'books', 'could', 'found', 'offensive'],
#  ['caps',
#   'removing',
#   'offending',
#   'books',
#   'would',
#   'basically',
#   'removing',
#   'half',
#   'books',
#   'library'],
#  ['young',
#   'adult',
#   'books',
#   'something',
#   'teens',
#   'drugs',
#   'violence',
#   'things',
#   'would',
#   'come',
#   'offensive'],
#  ['books', 'usually', 'ones', 'teenagers', 'read'],
#  ['reading', 'mean', 'actions', 'affected'],
#  ['types',
#   'books',
#   'read',
#   'purpose',
#   'entertainment',
#   'meant',
#   'harm',
#   'offend',
#   'anybody'],
#  ['secondly',
#   'think',
#   'people',
#   'right',
#   'choose',
#   'want',
#   'read',
#   'listen',
#   'watch'],
#  ['books', 'music', 'movies', 'magazines', 'sold', 'purpose'],
#  ['everyone', 'different', 'opinion', 'taste', 'like', 'dislike'],
#  ['finally', 'think', 'censoring', 'put', 'shelves', 'would', 'mistake'],
#  ['tons',
#   'great',
#   'books',
#   'movies',
#   'could',
#   'found',
#   'offensive',
#   'take',
#   'shelf',
#   'would',
#   'make',
#   'less',
#   'known'],
#  ['children', 'know', 'could', 'missing', 'great', 'stories'],
#  ['everyone', 'opinion', 'watching', 'children', 'understandable'],
#  ['censoring',
#   'available',
#   'library',
#   'would',
#   'make',
#   'finding',
#   'books',
#   'harder',
#   'people'],
#  ['libraries',
#   'meant',
#   'different',
#   'types',
#   'material',
#   'everyone',
#   'different',
#   'taste'],
#  ['time',
#   'went',
#   'caps',
#   'wheeling',
#   'one',
#   'time',
#   'went',
#   'caps',
#   'wheeling',
#   'person',
#   'person',
#   'person',
#   'person',
#   'went',
#   'organization'],
#  ['arrangements', 'trucks'],
#  ['person',
#   'caps',
#   'num',
#   'person',
#   'person',
#   'tracker',
#   'num',
#   'person',
#   'person',
#   'num',
#   'wheel',
#   'drive',
#   'jeep',
#   'caps'],
#  ['started', 'head', 'back', 'mountain', 'person', 'let', 'person', 'drive'],
#  ['person',
#   'see',
#   'well',
#   'night',
#   'wears',
#   'glasses',
#   'eye',
#   'sights',
#   'good'],
#  ['well',
#   'following',
#   'mountain',
#   'finally',
#   'got',
#   'pavement',
#   'person',
#   'going',
#   'pretty',
#   'fast',
#   'road',
#   'narrow',
#   'curving',
#   'road',
#   'first',
#   'time',
#   'ever'],
#  ['went',
#   'go',
#   'around',
#   'really',
#   'sharp',
#   'corner',
#   'got',
#   'two',
#   'wheels',
#   'flipped',
#   'right',
#   'front',
#   'slam',
#   'brakes',
#   'run'],
#  ['shut',
#   'truck',
#   'run',
#   'fast',
#   'could',
#   'helped',
#   'person',
#   'truck',
#   'turn',
#   'back',
#   'around',
#   'go',
#   'help',
#   'person',
#   'hes',
#   'already',
#   'top',
#   'truck',
#   'looks',
#   'person',
#   'ans',
#   'says',
#   'caps',
#   'look',
#   'truck',
#   'tried',
#   'many',
#   'times',
#   'roll',
#   'never',
#   'able',
#   'god',
#   'damn'],
#  ['started', 'laughing', 'got', 'chain', 'back', 'truck', 'pulled', 'back'],
#  ['really', 'quite', 'person', 'farted', 'started', 'laugh'],
#  ['well',
#   'person',
#   'found',
#   'got',
#   'hole',
#   'radiator',
#   'pull',
#   'back',
#   'house',
#   'seemed',
#   'like',
#   'longest',
#   'drive',
#   'ever',
#   'truck',
#   'weighs',
#   'way',
#   'mine',
#   'pull',
#   'home',
#   'caps',
#   'wheel',
#   'drive',
#   'cant',
#   'go',
#   'thirty',
#   'caps',
#   'wheel',
#   'drive',
#   'stuff',
#   'break'],
#  ['finally',
#   'get',
#   'house',
#   'dad',
#   'comes',
#   'side',
#   'saw',
#   'truck',
#   'really',
#   'pissed',
#   'gave',
#   'truck',
#   'graduation',
#   'present',
#   'messed'],
#  ['finally',
#   'cooled',
#   'cause',
#   'said',
#   'one',
#   'hurt',
#   'glad',
#   'went',
#   'house',
#   'ate',
#   'dinner',
#   'went',
#   'bed'],
#  ['moral', 'story', 'careful', 'things', 'happen', 'unexpected'],
#  ['day', 'date', 'way', 'school'],
#  ['friend', 'person', 'walking', 'lived', 'street'],
#  ['lived', 'houses', 'away', 'always', 'walked', 'school', 'together'],
#  ['well',
#   'particular',
#   'day',
#   'decided',
#   'wear',
#   'pair',
#   'sneakers',
#   'absolutely',
#   'traction',
#   'bottom',
#   'shoe',
#   'snow'],
#  ['slipped', 'times', 'never', 'fell'],
#  ['laughing',
#   'would',
#   'right',
#   'middle',
#   'saying',
#   'something',
#   'id',
#   'almost',
#   'fall'],
#  ['got', 'school', 'started', 'telling', 'everyone', 'joined'],
#  ['pretty',
#   'funny',
#   'even',
#   'school',
#   'would',
#   'almost',
#   'fall',
#   'floors',
#   'wet',
#   'dried',
#   'snow'],
#  ['thought',
#   'walking',
#   'home',
#   'changing',
#   'shoes',
#   'would',
#   'wait',
#   'lunch',
#   'leave',
#   'school',
#   'would',
#   'get',
#   'trouble'],
#  ['first',
#   'period',
#   'found',
#   'puddle',
#   'water',
#   'started',
#   'sliding',
#   'across',
#   'fun'],
#  ['friends', 'tried', 'shoes', 'much', 'traction'],
#  ['bell', 'rang', 'second', 'period', 'start', 'headed', 'class'],
#  ['fun', 'trying', 'get', 'class', 'slid', 'around', 'everywhere'],
#  ['got', 'class', 'teacher', 'told', 'going', 'field', 'trip', 'ponds'],
#  ['skip', 'teacher', 'walking', 'right', 'behind'],
#  ['boarded', 'bus', 'started', 'heading', 'ponds'],
#  ['teacher', 'called', 'names', 'make', 'sure'],
#  ['must', 'done', 'every', 'num', 'minutes'],
#  ['pretty', 'annoying'],
#  ['bus',
#   'driver',
#   'playing',
#   'country',
#   'music',
#   'really',
#   'mind',
#   'country',
#   'music',
#   'day',
#   'really',
#   'want',
#   'listen'],
#  ['went', 'get', 'ipod', 'pocket', 'found'],
#  ['left', 'house', 'rushing', 'get', 'school'],
#  ['finally', 'arrived', 'ponds', 'unloaded', 'bus', 'begin', 'field', 'trip'],
#  ['teacher',
#   'told',
#   'us',
#   'go',
#   'close',
#   'ponds',
#   'fell',
#   'would',
#   'soaked',
#   'bus',
#   'driver',
#   'let',
#   'us',
#   'back',
#   'bus'],
#  ['thought', 'talking', 'smack', 'asked', 'bus', 'driver', 'serious'],
#  ['bus',
#   'driver',
#   'told',
#   'got',
#   'wet',
#   'would',
#   'wait',
#   'us',
#   'dry',
#   'get',
#   'seats',
#   'wet'],
#  ['thought', 'bunch', 'bull'],
#  ['met',
#   'tour',
#   'guide',
#   'dude',
#   'started',
#   'listening',
#   'tell',
#   'us',
#   'history',
#   'ponds',
#   'used'],
#  ['walking', 'around', 'ponds', 'started', 'slide', 'ground'],
#  ['grabbed', 'onto', 'friend', 'fall', 'pretty', 'bad', 'balance', 'fell'],
#  ['everyone', 'started', 'laughing', 'well'],
#  ['friend', 'think', 'funny', 'first'],
#  ['got', 'started', 'laughing', 'joked', 'stand', 'right'],
#  ['way',
#   'back',
#   'school',
#   'talked',
#   'learned',
#   'would',
#   'want',
#   'go',
#   'back',
#   'learn',
#   'even',
#   'volunteer',
#   'work',
#   'ponds'],
#  ['thought', 'would', 'pretty', 'fun', 'slip', 'around', 'whole', 'time'],
#  ['unloaded', 'bus', 'headed', 'school'],
#  ['found',
#   'little',
#   'puddle',
#   'found',
#   'earlier',
#   'dried',
#   'got',
#   'running',
#   'start',
#   'slid',
#   'across'],
#  ['fall', 'time'],
#  ['bus',
#   'brought',
#   'us',
#   'back',
#   'time',
#   'last',
#   'class',
#   'day',
#   'unfortunately',
#   'caps'],
#  ['got', 'gym', 'asked', 'teacher', 'going', 'playing'],
#  ['told',
#   'going',
#   'upstairs',
#   'wrestling',
#   'mats',
#   'play',
#   'dodge',
#   'ball',
#   'game'],
#  ['upstairs', 'wrestling', 'mats', 'small', 'area', 'went', 'small', 'class'],
#  ['lucked', 'big', 'time', 'take', 'shoes', 'play', 'mats'],
#  ['got', 'done', 'caps', 'bell', 'rang', 'tell', 'us', 'school'],
#  ['got', 'dressed', 'normal', 'clothes', 'headed', 'home'],
#  ['friend', 'person', 'waiting', 'outside'],
#  ['started', 'heading', 'home', 'slide', 'around', 'every', 'step', 'took'],
#  ['sun', 'melted', 'top', 'layer', 'snow', 'turned', 'ice'],
#  ['looked', 'location', 'laughed'],
#  ['laughed'],
#  ['whole', 'way', 'home', 'skating', 'ice'],
#  ['really', 'fun', 'day'],
#  ['except', 'right', 'got', 'home', 'fell', 'deck', 'step', 'icy'],
#  ['including',
#   'bit',
#   'taking',
#   'test',
#   'hidiscus',
#   'budding',
#   'provides',
#   'sense',
#   'closeur',
#   'lesson',
#   'otherwise',
#   'open',
#   'ending'],
#  ['saeng',
#   'fails',
#   'drivers',
#   'test',
#   'early',
#   'story',
#   'way',
#   'home',
#   'buys',
#   'hibiscus'],
#  ['reader', 'really', 'see', 'connection', 'last', 'paragraph'],
#  ['hibiscus', 'represents', 'perserverence', 'strength'],
#  ['harsh', 'winter', 'hibiscus', 'bloom', 'ard', 'continue', 'live'],
#  ['even',
#   'moving',
#   'vietnam',
#   'struggling',
#   'adapt',
#   'saeng',
#   'must',
#   'recover',
#   'ard',
#   'keep',
#   'trying'],
#  ['like', 'flower', 'blooming', 'saeng'],
#  ['take', 'test', 'second', 'time', 'pass'],
#  ['adapt', 'environment', 'keep', 'going', 'like', 'hibiscus'],
#  ['obstacles',
#   'builders',
#   'empire',
#   'state',
#   'building',
#   'develop',
#   'hope',
#   'get',
#   'greater',
# ...
#   'sultans',
#   'briskly',
#   'walked',
#   'white',
#   'plastic',
#   'suddenly',
#   'pulled',
#   'rectangular',
#   'favor',
#   'caps',
#   'caps'],
#  ['wash'],
#  [],
#  ['kind', 'much', 'man'],
#  ['replied'],
#  ['goes', 'show', 'prince', 'really', 'says'],
#  ['complain', 'course'],
#  [],
#  ['organization', 'caps', 'world', 'without', 'computers'],
#  ['would', 'get', 'information'],
#  ['would', 'religh', 'television', 'magaziens', 'information', 'changed'],
#  ['would', 'ever', 'get', 'reports', 'done', 'work', 'home', 'work'],
#  ['know', 'many', 'people', 'write', 'neat', 'one', 'read'],
#  ['basically',
#   'computers',
#   'effect',
#   'lives',
#   'much',
#   'good',
#   'way',
#   'would',
#   'chaos'],
#  ['computers',
#   'allow',
#   'people',
#   'learn',
#   'type',
#   'improve',
#   'around',
#   'skills',
#   'hand',
#   'eye',
#   'coordination',
#   'let',
#   'us',
#   'connect',
#   'places',
#   'familiar',
#   'see',
#   'family',
#   'members',
#   'allow',
#   'people',
#   'online',
#   'education',
#   'help',
#   'economy'],
#  ['computers',
#   'effect',
#   'us',
#   'good',
#   'way',
#   'change',
#   'every',
#   'day',
#   'lives',
#   'caps',
#   'children',
#   'days',
#   'cannot',
#   'type'],
#  ['recent',
#   'study',
#   'done',
#   'organization',
#   'showed',
#   'percent',
#   'kids',
#   'older',
#   'num',
#   'already',
#   'know',
#   'type',
#   'keyboard'],
#  ['computers',
#   'big',
#   'effect',
#   'us',
#   'many',
#   'skills',
#   'people',
#   'ignoledge',
#   'enough'],
#  ['thoes', 'kids', 'know', 'type', 'spell', 'better'],
#  ['remember', 'one', 'time', 'middle', 'writing', 'report', 'online'],
#  ['got', 'num', 'word', 'know', 'always', 'trubble', 'spelling'],
#  ['took', 'time', 'typed', 'one', 'letter', 'time', 'correct'],
#  ['example',
#   'shows',
#   'computers',
#   'effect',
#   'everyones',
#   'lifes',
#   'even',
#   'younger',
#   'kids'],
#  ['way',
#   'get',
#   'information',
#   'computers',
#   'like',
#   'way',
#   'hands',
#   'get',
#   'information',
#   'brain',
#   'move'],
#  ['example', 'babies', 'learn', 'walk', 'religh', 'brains', 'show', 'done'],
#  ['like',
#   'natural',
#   'disaster',
#   'earthquake',
#   'location',
#   'religh',
#   'computers',
#   'show',
#   'us',
#   'tell',
#   'us',
#   'going',
#   'something',
#   'like',
#   'could',
#   'happen'],
#  ['computers',
#   'effect',
#   'us',
#   'way',
#   'many',
#   'things',
#   'might',
#   'never',
#   'know',
#   'world',
#   'without'],
#  ['computers',
#   'effect',
#   'families',
#   'everyday',
#   'lives',
#   'giving',
#   'online',
#   'educations'],
#  ['num',
#   'year',
#   'old',
#   'cusin',
#   'told',
#   'happy',
#   'mom',
#   'could',
#   'go',
#   'back',
#   'college',
#   'home',
#   'could',
#   'spend',
#   'time',
#   'together'],
#  ['know',
#   'might',
#   'think',
#   'computers',
#   'make',
#   'families',
#   'get',
#   'apart',
#   'actually',
#   'bring',
#   'closer',
#   'together'],
#  ['one', 'choice', 'computers', 'effect', 'us', 'good', 'way'],
#  ['help',
#   'us',
#   'learn',
#   'type',
#   'connect',
#   'us',
#   'world',
#   'bring',
#   'families',
#   'closer',
#   'together'],
#  ['without', 'computers', 'today'],
#  ['dear', 'caps', 'caps', 'would', 'want', 'spare', 'time'],
#  ['would',
#   'go',
#   'outside',
#   'maybe',
#   'caps',
#   'soccer',
#   'ball',
#   'around',
#   'kids',
#   'grab',
#   'bag',
#   'chips',
#   'log',
#   'onto',
#   'facebook',
#   'email'],
#  ['question', 'computers', 'negative', 'positive', 'effect', 'people'],
#  ['believe', 'computers', 'negative', 'effect'],
#  ['talking', 'friends', 'computer', 'let', 'learn', 'social', 'skills'],
#  ['going', 'computer', 'also', 'addicting'],
#  ['finally', 'take', 'away', 'exercise', 'need'],
#  ['caps',
#   'careful',
#   'consideration',
#   'agree',
#   'computers',
#   'negative',
#   'effect',
#   'people'],
#  ['facebook',
#   'ichat',
#   'email',
#   'fun',
#   'easy',
#   'ways',
#   'talk',
#   'friends',
#   'family',
#   'online'],
#  ['however', 'really', 'gaining', 'social', 'skills'],
#  ['talking',
#   'friends',
#   'family',
#   'online',
#   'help',
#   'good',
#   'social',
#   'skills'],
#  ['first',
#   'meet',
#   'someone',
#   'person',
#   'likely',
#   'want',
#   'caps',
#   'caps',
#   'say',
#   'act'],
#  ['typing', 'keyboard', 'really', 'let', 'interact', 'people'],
#  ['caps', 'invite', 'someone', 'go', 'lunch', 'family', 'istead'],
#  ['computers', 'also', 'addicting'],
#  ['say', 'log', 'onto', 'computer', 'might', 'next', 'hours'],
#  ['case', 'many', 'people'],
#  ['going', 'computer', 'addicting'],
#  ['il',
#   'caps',
#   'everyone',
#   'using',
#   'computer',
#   'daily',
#   'basis',
#   'vast',
#   'majority',
#   'people'],
#  ['facebook',
#   'see',
#   'number',
#   'people',
#   'online',
#   'one',
#   'hundred',
#   'even',
#   'two',
#   'hundred',
#   'time',
#   'goes',
#   'number',
#   'increases'],
#  ['computer', 'addicting', 'leads', 'getting', 'enough', 'exercise'],
#  ['doctors',
#   'say',
#   'adults',
#   'kids',
#   'get',
#   'atleast',
#   'hour',
#   'exercise',
#   'day'],
#  ['going', 'computer', 'takes', 'away', 'time'],
#  ['instead',
#   'sitting',
#   'computer',
#   'hour',
#   'could',
#   'getting',
#   'hour',
#   'exercise'],
#  ['instead', 'lot', 'times', 'someone', 'caps', 'computer', 'snack', 'goes'],
#  ['adds',
#   'onto',
#   'fact',
#   'caps',
#   'getting',
#   'exercise',
#   'important',
#   'stay',
#   'healthy'],
#  ['caps',
#   'would',
#   'feel',
#   'lot',
#   'better',
#   'went',
#   'run',
#   'instead',
#   'going',
#   'computer'],
#  ['probably',
#   'saying',
#   'time',
#   'manage',
#   'people',
#   'would',
#   'rather',
#   'exercise'],
#  ['people', 'see', 'computer', 'caps', 'kind', 'example', 'set'],
#  ['everyone',
#   'limited',
#   'time',
#   'computer',
#   'would',
#   'feel',
#   'lot',
#   'better',
#   'social'],
#  ['trust', 'agree', 'computers', 'negative', 'effect', 'people'],
#  ['excerpt',
#   'many',
#   'obstacles',
#   'builders',
#   'empire',
#   'state',
#   'building',
#   'faced',
#   'attempting',
#   'allow',
#   'dirigibles',
#   'dock'],
#  ['problems',
#   'dirigible',
#   'held',
#   'single',
#   'cable',
#   'tether',
#   'would',
#   'add',
#   'stress',
#   'building',
#   'frame',
#   'wind',
#   'pressure',
#   'help',
#   'either',
#   'stated',
#   'caps',
#   'num'],
#  ['another',
#   'issue',
#   'said',
#   'caps',
#   'num',
#   'dirigibles',
#   'outside',
#   'united',
#   'states',
#   'used',
#   'hydrogen',
#   'rather',
#   'helium',
#   'hydrogen',
#   'highly',
#   'flammable',
#   'also',
#   'caps',
#   'num',
#   'owners',
#   'empire',
#   'state',
#   'building',
#   'realized',
#   'much',
#   'worse',
#   'accident',
#   'could',
#   'taken',
#   'place',
#   'densely',
#   'populated',
#   'area',
#   'town',
#   'new',
#   'york'],
#  ['problems', 'builders', 'faced'],
#  ['heat', 'dessert', 'humidity', 'things', 'affect', 'cyclist', 'journey'],
#  ['first',
#   'heat',
#   'heat',
#   'making',
#   'thirsty',
#   'water',
#   'caps',
#   'running',
#   'row'],
#  ['example',
#   'narrator',
#   'describes',
#   'water',
#   'bottles',
#   'tantalizing',
#   'sips',
#   'means',
#   'day',
#   'hot',
#   'running',
#   'water'],
#  ['second',
#   'dessert',
#   'narrator',
#   'one',
#   'around',
#   'deserts',
#   'usually',
#   'diserted'],
#  ['example',
#   'narrator',
#   'exclaims',
#   'one',
#   'sight',
#   'building',
#   'car',
#   'structure',
#   'kind',
#   'caps',
#   'clearly',
#   'states',
#   'could',
#   'dessert',
#   'one',
#   'wants'],
#  ['lastly',
#   'humidity',
#   'hot',
#   'humidity',
#   'comes',
#   'plan',
#   'makes',
#   'sky',
#   'dry',
#   'seen',
#   'hotter',
#   'usually'],
#  ['heat', 'dessert', 'humidity', 'things', 'affect', 'cyclist', 'journey'],
#  ['mood', 'auther', 'suttle', 'time', 'kinda', 'depresed'],
#  ['way', 'narator', 'sounds', 'bad', 'mood'],
#  ['sometimes', 'bad', 'mood', 'suttle', 'mood'],
#  ['construction',
#   'mooring',
#   'mast',
#   'atop',
#   'empire',
#   'state',
#   'building',
#   'builders',
#   'caps',
#   'many',
#   'challenges'],
#  ['put', 'spire', 'top', 'building'],
#  ['weight', 'dirigible', 'could', 'destroy'],
#  ['construction',
#   'team',
#   'needed',
#   'go',
#   'back',
#   'reinforce',
#   'entire',
#   'framework',
#   'building'],
#  ['obstacles',
#   'way',
#   'included',
#   'low',
#   'flying',
#   'aircraft',
#   'laws',
#   'difficult',
#   'weather',
#   'conditions',
#   'safety',
#   'derigible',
#   'crashed',
#   'new',
#   'york'],
#  ['reasons', 'mooring', 'mast', 'doomed', 'start'],
#  ['ever', 'someone', 'move', 'away', 'wanted', 'keep', 'touch'],
#  ['well', 'computer', 'allows', 'happen'],
#  ['caps', 'gives', 'students', 'learn', 'different', 'places'],
#  ['people', 'much'],
#  ['people', 'hire'],
#  ['first', 'computers', 'allow', 'talk', 'online', 'friends', 'family'],
#  ['example',
#   'using',
#   'email',
#   'caps',
#   'video',
#   'chat',
#   'example',
#   'friend',
#   'moved',
#   'away',
#   'email',
#   'back',
#   'forth',
#   'keep',
#   'touch'],
#  ['caps',
#   'allows',
#   'people',
#   'chat',
#   'instintly',
#   'upload',
#   'pictures',
#   'videos'],
#  ['examples',
#   'caps',
#   'caps',
#   'pictures',
#   'baby',
#   'cousins',
#   'people',
#   'see',
#   'growing'],
#  ['lastly', 'buessnesses', 'use', 'webcam', 'talk', 'people'],
#  ['say',
#   'boss',
#   'see',
#   'employees',
#   'withness',
#   'could',
#   'hook',
#   'web',
#   'cam',
#   'conversation'],
#  ['computers',
#   'allow',
#   'people',
#   'caps',
#   'computers',
#   'caps',
#   'people',
#   'learn',
#   'things',
#   'example',
#   'student',
#   'rod',
#   'make',
#   'topic',
#   'could',
#   'type',
#   'topic',
#   'website',
#   'like',
#   'bring',
#   'google',
#   'could',
#   'find',
#   'answers',
#   'needed',
#   'help',
#   'project'],
#  ['caps',
#   'family',
#   'wanted',
#   'go',
#   'see',
#   'could',
#   'search',
#   'find',
#   'hotell',
#   'sites',
#   'might',
#   'want',
#   'see',
#   'computer',
#   'allows',
#   'people',
#   'reader',
#   'read',
#   'hand',
#   'writing'],
#  ['caps', 'help', 'pay', 'taxes'],
#  ['example',
#   'turbo',
#   'tax',
#   'online',
#   'program',
#   'allows',
#   'people',
#   'pay',
#   'taxes',
#   'online',
#   'remembers',
#   'every',
#   'tax',
#   'paid'],
#  ['company',
#   'sends',
#   'notice',
#   'saying',
#   'havent',
#   'payed',
#   'bill',
#   'go',
#   'turbo',
#   'tax',
#   'check'],
#  ['reader', 'ways', 'people', 'enjoy', 'computers'],
#  ['allow',
#   'people',
#   'talk',
#   'friends',
#   'family',
#   'email',
#   'caps',
#   'caps',
#   'webcam'],
#  ['caps',
#   'give',
#   'people',
#   'ability',
#   'learn',
#   'information',
#   'faraway',
#   'places',
#   'people'],
#  ['lastly', 'bad', 'computer'],
#  ['allow', 'people', 'pay', 'taxes', 'online', 'caps', 'type', 'papers'],
#  ['computers',
#   'needed',
#   'day',
#   'age',
#   'else',
#   'people',
#   'would',
#   'able',
#   'survive',
#   'without'],
#  ['reader', 'reasons', 'people', 'easily', 'computers'],
#  ['throughout',
#   'history',
#   'literature',
#   'many',
#   'books',
#   'banned',
#   'public',
#   'libraries',
#   'shelves'],
#  ['somehow', 'offensive', 'certain', 'people'],
#  ['even',
#   'books',
#   'include',
#   'magic',
#   'fiction',
#   'expelled',
#   'societies',
#   'simply',
#   'certain',
#   'religions',
#   'cultural',
#   'backgrounds'],
#  ['believe',
#   'never',
#   'piece',
#   'literature',
#   'completely',
#   'banned',
#   'public',
#   'eye'],
#  ['book', 'banned', 'piece', 'history', 'removed', 'others', 'sight'],
#  ['book', 'month', 'banned', 'date', 'could', 'read', 'mother', 'father'],
#  ['future', 'children', 'could', 'also', 'never', 'able', 'read'],
#  ['materials',
#   'removed',
#   'public',
#   'generally',
#   'removed',
#   'one',
#   'specific',
#   'group',
#   'complains',
#   'content'],
#  ['eight',
#   'years',
#   'old',
#   'remember',
#   'seeing',
#   'news',
#   'people',
#   'location',
#   'caps',
#   'caps',
#   'countries',
#   'burning',
#   'books',
#   'caps',
#   'caps',
#   'series',
#   'contained',
#   'magic',
#   'ridiculous',
#   'fiction'],
#  ['maybe',
#   'burned',
#   'caps',
#   'looked',
#   'upon',
#   'story',
#   'fictional',
#   'stories',
#   'mean',
#   'banned',
#   'libraries'],
#  ['caps',
#   'caps',
#   'series',
#   'one',
#   'popular',
#   'pieces',
#   'literature',
#   'generation',
#   'generations',
#   'mine',
#   'able',
#   'enjoy',
#   'much'],
#  ['beginning', 'caps', 'caps', 'caps', 'caps', 'starting', 'discriminated'],
#  ['treated', 'sub', 'humans', 'like', 'example'],
#  ['night',
#   'date',
#   'called',
#   'caps',
#   'radical',
#   'caps',
#   'caps',
#   'supporters',
#   'burned',
#   'caps',
#   'houses',
#   'stores',
#   'even',
#   'books'],
#  ['books',
#   'could',
#   'copies',
#   'yet',
#   'organization',
#   'let',
#   'hate',
#   'overcome',
#   'destroyed',
#   'pieces',
#   'caps',
#   'literature'],
#  ['organization',
#   'found',
#   'caps',
#   'work',
#   'offensive',
#   'generations',
#   'caps',
#   'caps',
#   'caps',
#   'never',
#   'read',
#   'books',
#   'burned',
#   'caps'],
#  ['katherine',
#   'paterson',
#   'quote',
#   'says',
#   'right',
#   'remove',
#   'book',
#   'shelf',
#   'work',
#   'abhor',
#   'also',
#   'exactly',
#   'right',
#   'everyone',
#   'else'],
#  ['books', 'left', 'shelf', 'us'],
#  ['believe', 'correct', 'quote'],
#  ['literature',
#   'keeps',
#   'censored',
#   'none',
#   'left',
#   'future',
#   'generations',
#   'enjoy'],
#  ['literature', 'censored', 'even', 'radical', 'magical', 'fictional'],
#  ['censorship', 'continues', 'future', 'literature', 'doomed'],
#  ['author',
#   'concludes',
#   'story',
#   'paragraph',
#   'show',
#   'needs',
#   'adapt',
#   'new',
#   'country'],
#  ['wants', 'wait', 'hibiscus', 'budding'],
#  ['plant',
#   'budding',
#   'shows',
#   'adapting',
#   'new',
#   'environment',
#   'like',
#   'saeng'],
#  ['story', 'shows', 'saeng', 'used', 'new', 'country'],
#  ['cries', 'sees', 'plants', 'reminds', 'old', 'home'],
#  ['plant', 'also', 'comforts'],
#  ['addapts', 'new', 'country', 'take', 'test'],
#  ['obstacles', 'builders', 'faced', 'mainly', 'safety'],
#  ['safety', 'important', 'many', 'people', 'new', 'york'],
#  ['another',
#   'problem',
#   'dirigibles',
#   'outside',
#   'united',
#   'states',
#   'hydrogen',
#   'instead',
#   'helium'],
#  ['high',
#   'height',
#   'wind',
#   'strong',
#   'blimps',
#   'held',
#   'front',
#   'back',
#   'would',
#   'swing',
#   'uncontrolably'],
#  ['blimp',
#   'easily',
#   'blown',
#   'close',
#   'building',
#   'sharp',
#   'spires',
#   'pop',
#   'winds'],
#  ['alot',
#   'things',
#   'could',
#   'go',
#   'wrong',
#   'time',
#   'think',
#   'right',
#   'decision',
#   'stop',
#   'idea',
#   'mooring',
#   'mast'],
#  ['matter', 'nationality', 'get', 'along', 'anyone'],
#  ['shows',
#   'home',
#   'least',
#   'wonderful',
#   'caps',
#   'nice',
#   'smells',
#   'food',
#   'people'],
#  ['unexplainable', 'happy', 'grateful', 'parents'],
#  ['caps', 'heaven', 'earth'],
#  ['warmth',
#   'kitchen',
#   'humble',
#   'house',
#   'cuban',
#   'feast',
#   'always',
#   'filled',
#   'air',
#   'scent',
#   'music',
#   'love',
#   'life'],
#  ['never', 'forget', 'house', 'gracious', 'neigh', 'bor', 'hood'],
#  ['one',
#   'time',
#   'got',
#   'birthday',
#   'money',
#   'wanted',
#   'buy',
#   'electric',
#   'scooter',
#   'caps',
#   'weekends',
#   'always',
#   'waited',
#   'dad',
#   'get',
#   'home',
#   'caps',
#   'could',
#   'look',
#   'internet',
#   'always',
#   'got',
#   'home',
#   'looked',
#   'never',
#   'liked',
#   'one',
#   'day',
#   'work',
#   'caps',
#   'looked',
#   'found',
#   'two',
#   'liked'],
#  ['one', 'gas', 'scooter', 'one', 'wa', 'electric', 'scooter'],
#  ['went',
#   'look',
#   'gas',
#   'scooter',
#   'lot',
#   'money',
#   'bounch',
#   'snacks',
#   'caps',
#   'called',
#   'person',
#   'electric',
#   'scooter',
#   'like',
#   'gas',
#   'scooter',
#   'went'],
#  [],
#  ['got',
#   'agosumtied',
#   'money',
#   'oriyiek',
#   'num',
#   'money',
#   'caps',
#   'got',
#   'home',
#   'rode',
#   'three',
#   'days'],
#  ['one', 'night', 'went', 'garage', 'went', 'control'],
#  ['thought', 'fuse'],
#  ['controller',
#   'part',
#   'everything',
#   'hooks',
#   'caps',
#   'called',
#   'company',
#   'ordered',
#   'part',
#   'sent',
#   'us',
#   'wrong',
#   'one',
#   'told',
#   'right',
#   'one',
#   'sent',
#   'one',
#   'caps',
#   'fell',
#   'desk',
#   'forgot',
#   'caps',
#   'ordered',
#   'said',
#   'time',
#   'sending',
#   'right',
#   'controls'],
#  ['caps', 'waiting', 'num', 'year', 'num', 'months'],
#  ['ever', 'found', 'book', 'offensive'],
#  ['many', 'people', 'say'],
#  ['might', 'agree', 'point', 'book', 'certain', 'viewpoints', 'text'],
#  ['happens', 'people', 'stop', 'reading', 'book', 'books', 'category'],
#  ['certain',
#   'materials',
#   'removed',
#   'shelves',
#   'found',
#   'offending',
#   'certain',
#   'people'],
#  ['everyone', 'opinions', 'would', 'left', 'without', 'books'],
#  ['public',
#   'library',
#   'citizens',
#   'city',
#   'request',
#   'certain',
#   'books',
#   'movies',
#   'music',
#   'magazines',
#   'put',
#   'shelves'],
#  ['blessed',
#   'available',
#   'someone',
#   'cannot',
#   'afford',
#   'cerain',
#   'books',
#   'always',
#   'rely',
#   'library'],
#  ['many', 'people', 'thankful', 'system'],
#  ['certain',
#   'people',
#   'library',
#   'want',
#   'order',
#   'certain',
#   'books',
#   'requested',
#   'citizens',
#   'find',
#   'offensive',
#   'would',
#   'happen'],
#  ...]

# %%
#build the vectorizer with maximum featuroes of 300
num_features = 300 
min_word_count = 40
num_workers = 4
context = 10
downsampling = 1e-3
model = Word2Vec(sentences, workers=num_workers, vector_size=num_features, min_count = min_word_count, window = context, 
                 sample = downsampling)

# %%
#save the vectorizer in .bin file
model.wv.save_word2vec_format('word2vecmodel.bin', binary=True)

# %%
#get the training vectors
clean_train_essays = []
for essay_v in train_essays:
        clean_train_essays.append(essay_to_wordlist(essay_v))
trainDataVecs = getAvgFeatureVecs(clean_train_essays, model, num_features)
 
#get the testing vectors
clean_test_essays = []
for essay_v in test_essays:
    clean_test_essays.append(essay_to_wordlist( essay_v))
testDataVecs = getAvgFeatureVecs( clean_test_essays, model, num_features )
    
#convert the vectors to numpy array
trainDataVecs = np.array(trainDataVecs)
testDataVecs = np.array(testDataVecs)

# Reshaping train and test vectors to 3 dimensions. (1 represnts one timestep)
trainDataVecs = np.reshape(trainDataVecs, (trainDataVecs.shape[0], 1, trainDataVecs.shape[1]))
testDataVecs = np.reshape(testDataVecs, (testDataVecs.shape[0], 1, testDataVecs.shape[1]))

# %% [markdown]
# # model building

# %%
from keras.layers import Embedding, LSTM, Dense, Dropout, Lambda, Flatten
from keras.models import Sequential, load_model, model_from_config
import keras.backend as K
# Out:
# Using TensorFlow backend.
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
model = Sequential()
model.add(LSTM(300, dropout=0.4, recurrent_dropout=0.4, input_shape=[1, 300], return_sequences=True))
model.add(LSTM(64, recurrent_dropout=0.4))
model.add(Dropout(0.5))
model.add(Dense(1, activation='relu'))
# Out:
# WARNING:tensorflow:From C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])
# Out:
# WARNING:tensorflow:From C:\Users\sandhya yenimi reddy\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(trainDataVecs, y_train, batch_size=64, epochs=10)
# Out:
# Epoch 1/10
# 10380/10380 [==============================] - 5s 465us/step - loss: 5.2998 - mean_absolute_error: 1.2362
# Epoch 2/10
# 10380/10380 [==============================] - 5s 485us/step - loss: 5.2791 - mean_absolute_error: 1.2350
# Epoch 3/10
# 10380/10380 [==============================] - 5s 497us/step - loss: 5.3501 - mean_absolute_error: 1.2460
# Epoch 4/10
# 10380/10380 [==============================] - 5s 496us/step - loss: 5.2453 - mean_absolute_error: 1.2439
# Epoch 5/10
#  3136/10380 [========>.....................] - ETA: 3s - loss: 5.2650 - mean_absolute_error: 1.2175

# %%
testDataVecs.shape
# Out:
# (2596, 1, 300)

# %%
y_pred = model.predict(testDataVecs)

# %%
y_pred
# Out:
# array([[11.495794 ],
#        [17.46849  ],
#        [ 2.9602134],
#        ...,
#        [ 2.002942 ],
#        [ 2.7216907],
#        [ 2.8064475]], dtype=float32)

# %%
model.save('final_lstm.h5')

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test,y_pred)
accuracy
# Out:
# 0.9408386107051878
